# %%
import pandas as pd

# %%
tfl_df = pd.read_csv('tfl-daily-cycle-hires.csv')

# %%
tfl_df.dtypes
# Out:
# Day                         object
# Number of Bicycle Hires    float64
# Unnamed: 2                 float64
# dtype: object

# %%
# dropping unnecessary column
tfl_df.drop(columns='Unnamed: 2', inplace=True)

# %%
tfl_df
# Out:
#              Day  Number of Bicycle Hires
# 0     30/07/2010                   6897.0
# 1     31/07/2010                   5564.0
# 2     01/08/2010                   4303.0
# 3     02/08/2010                   6642.0
# 4     03/08/2010                   7966.0
# ...          ...                      ...
# 4076  26/09/2021                  45120.0
# 4077  27/09/2021                  32167.0
# 4078  28/09/2021                  32539.0
# 4079  29/09/2021                  39889.0
# 4080  30/09/2021                  34070.0
#
# [4081 rows x 2 columns]

# %%
# changing data type
tfl_df['Day']=tfl_df['Day'].astype('datetime64')
# Out:
# c:\Python\Python39\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Python\Python39\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '31/07/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Python\Python39\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Python\Python39\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/08/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# ...

# %% [markdown]
# ![to_datetime.png](attachment:to_datetime.png)

# %%
# formatting output to show only month and year columns as string
tfl_df['Day']= pd.to_datetime(tfl_df['Day'],format='%d/%m/%Y')

# %%
tfl_df
# Out:
#             Day  Number of Bicycle Hires
# 0    2010-07-30                   6897.0
# 1    2010-07-31                   5564.0
# 2    2010-01-08                   4303.0
# 3    2010-02-08                   6642.0
# 4    2010-03-08                   7966.0
# ...         ...                      ...
# 4076 2021-09-26                  45120.0
# 4077 2021-09-27                  32167.0
# 4078 2021-09-28                  32539.0
# 4079 2021-09-29                  39889.0
# 4080 2021-09-30                  34070.0
#
# [4081 rows x 2 columns]

# %% [markdown]
# ![sort_values.png](attachment:sort_values.png)

# %%
# sorting values by the 'Number of Bicycle Hires' in descending order
tfl_df.sort_values(by='Number of Bicycle Hires', ascending=False, inplace=True)

# %%
# head() returns the first n rows (n is the argument you pass into the parenthesis), default is 5
tfl_df.head()
# Out:
#             Day  Number of Bicycle Hires
# 1805 2015-09-07                  73094.0
# 3592 2020-05-30                  70170.0
# 3587 2020-05-25                  67034.0
# 3606 2020-06-13                  65045.0
# 3613 2020-06-20                  64041.0

# %%
# tail() returns the last n rows (n is the argument you pass into the parenthesis), default is 5
tfl_df.tail()
# Out:
#            Day  Number of Bicycle Hires
# 151 2010-12-28                   3763.0
# 905 2013-01-20                   3728.0
# 555 2012-05-02                   3531.0
# 141 2010-12-18                   2805.0
# 142 2010-12-19                   2764.0

# %%
import datetime as dt

# %%
# strftime is a method in the datetime module that converts a datetime object to string and outputs in a specified format
tfl_df['Month / Year'] = tfl_df['Day'].dt.strftime('%b-%y')

# %%
tfl_df
# Out:
#             Day  Number of Bicycle Hires Month / Year
# 1805 2015-09-07                  73094.0       Sep-15
# 3592 2020-05-30                  70170.0       May-20
# 3587 2020-05-25                  67034.0       May-20
# 3606 2020-06-13                  65045.0       Jun-20
# 3613 2020-06-20                  64041.0       Jun-20
# ...         ...                      ...          ...
# 151  2010-12-28                   3763.0       Dec-10
# 905  2013-01-20                   3728.0       Jan-13
# 555  2012-05-02                   3531.0       May-12
# 141  2010-12-18                   2805.0       Dec-10
# 142  2010-12-19                   2764.0       Dec-10
#
# [4081 rows x 3 columns]

# %%
# the transpose() method transposes the rows and columns, the index row becomes the column headers
tfl_df.transpose()
# Out:
#                                         1805                 3592  \
# Day                      2015-09-07 00:00:00  2020-05-30 00:00:00
# Number of Bicycle Hires              73094.0              70170.0
# Month / Year                          Sep-15               May-20
#
#                                         3587                 3606  \
# Day                      2020-05-25 00:00:00  2020-06-13 00:00:00
# Number of Bicycle Hires              67034.0              65045.0
# Month / Year                          May-20               Jun-20
#
#                                         3613                 1833  \
# Day                      2020-06-20 00:00:00  2015-06-08 00:00:00
# Number of Bicycle Hires              64041.0              63963.0
# Month / Year                          Jun-20               Jun-15
#
#                                         3593                 3607  \
# Day                      2020-05-31 00:00:00  2020-06-14 00:00:00
# ...

# %%
# setting the index to the 'Month / Year' column
tfl_df.set_index(keys='Month / Year', inplace=True)

# %%
tfl_df.transpose()
# Out:
# Month / Year                          Sep-15               May-20  \
# Day                      2015-09-07 00:00:00  2020-05-30 00:00:00
# Number of Bicycle Hires              73094.0              70170.0
#
# Month / Year                          May-20               Jun-20  \
# Day                      2020-05-25 00:00:00  2020-06-13 00:00:00
# Number of Bicycle Hires              67034.0              65045.0
#
# Month / Year                          Jun-20               Jun-15  \
# Day                      2020-06-20 00:00:00  2015-06-08 00:00:00
# Number of Bicycle Hires              64041.0              63963.0
#
# Month / Year                          May-20               Jun-20  \
# Day                      2020-05-31 00:00:00  2020-06-14 00:00:00
# Number of Bicycle Hires              63116.0              57516.0
#
# Month / Year                          May-21               Jul-20  ...  \
# Day                      2021-05-06 00:00:00  2020-07-18 00:00:00  ...
# ...

# %%
column_index = ['A','B']
data_list = [[[1,2], 'nested list'],[2,'not a nested list'],[[1,2],'nested list 2']]

# %%
df=pd.DataFrame(data=data_list, columns=column_index)

# %%
df
# Out:
#         A                  B
# 0  [1, 2]        nested list
# 1       2  not a nested list
# 2  [1, 2]      nested list 2

# %%
# The explode() method transforms each element of a list into it's own row
df.explode(column='A')
# Out:
#    A                  B
# 0  1        nested list
# 0  2        nested list
# 1  2  not a nested list
# 2  1      nested list 2
# 2  2      nested list 2

# %% [markdown]
# ## Links and resources:
# * to_datetime: https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html
# * Date formatting: https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
# * Datetime module: https://docs.python.org/3/library/datetime.html
# * strftime: https://docs.python.org/3/library/datetime.html#strftime-strptime-behavior
# * transpose: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.transpose.html
# * explode: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.explode.html
