# %%
import numpy as np
import pandas as pd

# %%
cust_df=pd.read_csv("cust_dimen.csv")
market_df=pd.read_csv("market_fact.csv")
order_df=pd.read_csv("orders_dimen.csv")
prod_df=pd.read_csv("prod_dimen.csv")
ship_df=pd.read_csv("shipping_dimen.csv")

# %%
order_df.head()
# Out:
#    Order_ID  Order_Date Order_Priority Ord_id
# 0         3  13-10-2010            LOW  Ord_1
# 1       293  01-10-2012           HIGH  Ord_2
# 2       483  10-07-2011           HIGH  Ord_3
# 3       515  28-08-2010  NOT SPECIFIED  Ord_4
# 4       613  17-06-2011           HIGH  Ord_5

# %%
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
cust_df.iloc[:3]
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3

# %%
cust_df.loc[:4]
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %%
market_df.loc[2,"Sales"]
# Out:
# 4701.69

# %%
market_df.loc[5:8,["Sales",'Cust_id','Discount']]
# Out:
#        Sales    Cust_id  Discount
# 5   164.0200  Cust_1818      0.03
# 6    14.7600    Cust_26      0.01
# 7  3410.1575  Cust_1641      0.10
# 8   162.0000  Cust_1641      0.01

# %%
market_df.iloc[[3,7,8]]
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10              48
# Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01              33
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5456   729.34          14.30                 0.37
# Ord_4725  1137.91           0.99                 0.55
# Ord_4725    45.84           0.71                 0.52

# %%
market_df.head()
# Out:
#           Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5446   -30.51           3.60                 0.56
# Ord_5406     4.56           0.93                 0.54
# Ord_5446  1148.90           2.50                 0.59
# Ord_5456   729.34          14.30                 0.37
# Ord_5485  1219.87          26.30                 0.38

# %%
market_df.loc['Ord_5456']
# Out:
# Prod_id                   Prod_6
# Ship_id                 SHP_7625
# Cust_id                Cust_1818
# Sales                    2337.89
# Discount                    0.09
# Order_Quantity                43
# Profit                    729.34
# Shipping_Cost               14.3
# Product_Base_Margin         0.37
# Name: Ord_5456, dtype: object

# %% [markdown]
# # Slicing and Dicing

# %%
market_df.loc[market_df['Sales']>2000]
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08              35
# Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10              48
# Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.0100      0.01              43
# ...           ...       ...        ...        ...       ...             ...
# Ord_2624   Prod_4  SHP_3591  Cust_1006  4924.1350      0.07              28
# Ord_2696   Prod_4  SHP_3691  Cust_1006  2836.0505      0.01              25
# Ord_2722   Prod_1  SHP_3731  Cust_1006  3508.3300      0.04              21
# Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08              28
# Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03              23
#
# ...

# %%
market_df.loc[(market_df.Sales > 2000) & (market_df.Sales < 3000) & (market_df.Profit > 100)]
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_5205   Prod_4  SHP_7274  Cust_1749  2546.5235      0.09              26
# Ord_139   Prod_17   SHP_186    Cust_45  2671.2100      0.06              14
# Ord_239    Prod_4   SHP_332    Cust_45  2157.3085      0.00              38
# Ord_1673  Prod_17  SHP_2314   Cust_498  2027.5500      0.04              14
# ...           ...       ...        ...        ...       ...             ...
# Ord_2107   Prod_2  SHP_2882   Cust_785  2409.9600      0.07              32
# Ord_3570   Prod_4  SHP_4942  Cust_1266  2094.9780      0.06              44
# Ord_3592   Prod_4  SHP_4973  Cust_1266  2614.3705      0.07              25
# Ord_2696   Prod_4  SHP_3691  Cust_1006  2836.0505      0.01              25
# Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08              28
#
# ...

# %%
market_df.loc[(market_df.Sales > 2000) & (market_df.Sales < 3000) & (market_df.Profit > 100),"Prod_id"]
# Out:
# Ord_id
# Ord_5456     Prod_6
# Ord_5205     Prod_4
# Ord_139     Prod_17
# Ord_239      Prod_4
# Ord_1673    Prod_17
#              ...
# Ord_2107     Prod_2
# Ord_3570     Prod_4
# Ord_3592     Prod_4
# Ord_2696     Prod_4
# Ord_5353     Prod_4
# Name: Prod_id, Length: 328, dtype: object

# %%
market_df.loc[(market_df.Prod_id=="Prod_4") | (market_df.Sales > 2000)]
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08              35
# Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10              48
# Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.0100      0.01              43
# ...           ...       ...        ...        ...       ...             ...
# Ord_2696   Prod_4  SHP_3691  Cust_1006  2836.0505      0.01              25
# Ord_2722   Prod_1  SHP_3731  Cust_1006  3508.3300      0.04              21
# Ord_5435   Prod_4  SHP_7594  Cust_1798  1991.8985      0.07              20
# Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08              28
# Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03              23
#
# ...
