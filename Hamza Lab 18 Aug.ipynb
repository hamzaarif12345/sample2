# %%
import pandas as pd;
import numpy as np;

# %%
cust_df=pd.read_csv("cust_dimen.csv")
market_df=pd.read_csv("market_fact.csv")
order_df=pd.read_csv("orders_dimen.csv")
prod_df=pd.read_csv("prod_dimen.csv")
ship_df=pd.read_csv("shipping_dimen.csv")

# %%
cust_df.head()
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %%
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
order_df.head()
# Out:
#    Order_ID  Order_Date Order_Priority Ord_id
# 0         3  13-10-2010            LOW  Ord_1
# 1       293  01-10-2012           HIGH  Ord_2
# 2       483  10-07-2011           HIGH  Ord_3
# 3       515  28-08-2010  NOT SPECIFIED  Ord_4
# 4       613  17-06-2011           HIGH  Ord_5

# %%
prod_df.head()
# Out:
#   Product_Category            Product_Sub_Category Prod_id
# 0  OFFICE SUPPLIES          STORAGE & ORGANIZATION  Prod_1
# 1  OFFICE SUPPLIES                      APPLIANCES  Prod_2
# 2  OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES  Prod_3
# 3       TECHNOLOGY    TELEPHONES AND COMMUNICATION  Prod_4
# 4        FURNITURE              OFFICE FURNISHINGS  Prod_5

# %%
ship_df.head()
# Out:
#    Order_ID       Ship_Mode   Ship_Date Ship_id
# 0         3     REGULAR AIR  20-10-2010   SHP_1
# 1       293  DELIVERY TRUCK  02-10-2012   SHP_2
# 2       293     REGULAR AIR  03-10-2012   SHP_3
# 3       483     REGULAR AIR  12-07-2011   SHP_4
# 4       515     REGULAR AIR  30-08-2010   SHP_5

# %%
#select all order and select the sales of customer segment coprorate
df=pd.merge(market_df,cust_df,on='Cust_id')

# %%
df.loc[df.Customer_Segment=='CORPORATE',['Ord_id',"Sales"]]
# Out:
#         Ord_id    Sales
# 0     Ord_5446   136.81
# 1     Ord_5406    42.27
# 2     Ord_5446  4701.69
# 3     Ord_5456  2337.89
# 4     Ord_5485  4233.15
# ...        ...      ...
# 8385  Ord_1833   611.16
# 8386  Ord_2324   121.87
# 8387  Ord_2220    41.06
# 8388  Ord_4424   994.04
# 8389  Ord_4444   159.41
#
# [3076 rows x 2 columns]

# %%
df.shape
# Out:
# (8399, 14)

# %%
## All column customer segment is home office and profit graeter tahn 500
df.loc[(df.Customer_Segment=='HOME OFFICE') & (df.Profit>500) ]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 17    Ord_4471  Prod_15  SHP_6228  Cust_1521  13255.9300      0.02
# 237    Ord_597   Prod_4   SHP_816   Cust_209   4283.2350      0.10
# 239    Ord_597   Prod_4   SHP_816   Cust_209   4374.6865      0.05
# ...        ...      ...       ...        ...         ...       ...
# 8338  Ord_2107   Prod_2  SHP_2882   Cust_785   2409.9600      0.07
# 8343  Ord_2178   Prod_4  SHP_2968   Cust_785   6030.5800      0.09
# 8366  Ord_3593   Prod_3  SHP_4974  Cust_1274  12073.0600      0.03
# 8367  Ord_3593  Prod_15  SHP_4975  Cust_1274   6685.0500      0.09
# 8369  Ord_3633   Prod_3  SHP_5031  Cust_1274   1169.2600      0.02
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 7                 48  1137.91           0.99                 0.55
# ...

# %%
df.loc[(df.Customer_Name=="ALEX AVILA") &(df.Profit>500) &(df.Customer_Segment=="HOME OFFICE")]
# Out:
#       Ord_id Prod_id  Ship_id   Cust_id      Sales  Discount  Order_Quantity  \
# 237  Ord_597  Prod_4  SHP_816  Cust_209  4283.2350      0.10              44
# 239  Ord_597  Prod_4  SHP_816  Cust_209  4374.6865      0.05              43
#
#      Profit  Shipping_Cost  Product_Base_Margin Customer_Name  \
# 237  676.13           8.80                 0.59    ALEX AVILA
# 239  973.16           8.08                 0.57    ALEX AVILA
#
#              Province Region Customer_Segment
# 237  BRITISH COLUMBIA   WEST      HOME OFFICE
# 239  BRITISH COLUMBIA   WEST      HOME OFFICE

# %%
#sales greater than or equal to 300 and profiut greater than 1000
df.loc[(df.Sales>300) & (df.Profit>1000)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 17    Ord_4471  Prod_15  SHP_6228  Cust_1521  13255.9300      0.02
# ...        ...      ...       ...        ...         ...       ...
# 8317  Ord_2770   Prod_3  SHP_3802  Cust_1016   7535.9600      0.08
# 8343  Ord_2178   Prod_4  SHP_2968   Cust_785   6030.5800      0.09
# 8366  Ord_3593   Prod_3  SHP_4974  Cust_1274  12073.0600      0.03
# 8367  Ord_3593  Prod_15  SHP_4975  Cust_1274   6685.0500      0.09
# 8371  Ord_2624   Prod_4  SHP_3591  Cust_1006   4924.1350      0.07
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 2                 26  1148.90           2.50                 0.59
# ...

# %%
#select all order from product category office supplies and from corporate categories
df2=pd.merge(df,prod_df,on='Prod_id')
#prod_df.loc[(prod_df.Product_Category=="OFFICE SUPPLIES")&(prod_df.)]

# %%
df2.loc[(df2.Product_Category=="OFFICE SUPPLIES")&(df2.Customer_Segment=='CORPORATE')]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01
# 3     Ord_3730  Prod_16  SHP_5175  Cust_1314   459.08      0.04
# 7     Ord_4506  Prod_16  SHP_6273  Cust_1544    92.02      0.07
# 9     Ord_1551  Prod_16  SHP_2145   Cust_531   184.77      0.00
# 11    Ord_1429  Prod_16  SHP_1976   Cust_510   539.06      0.05
# ...        ...      ...       ...        ...      ...       ...
# 7545  Ord_4629   Prod_1  SHP_6447  Cust_1587   848.19      0.06
# 7546  Ord_4604   Prod_1  SHP_6403  Cust_1522   234.24      0.09
# 7551  Ord_3543   Prod_1  SHP_4905  Cust_1266  1184.11      0.07
# 7552  Ord_2722   Prod_1  SHP_3731  Cust_1006  3508.33      0.04
# 7553  Ord_4424   Prod_1  SHP_6165  Cust_1519   994.04      0.03
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23  -30.51           3.60                 0.56
# ...

# %%
df3=pd.merge(df2,ship_df,on="Ship_id")

# %%
df4=pd.merge(df3,order_df,on="Ord_id")

# %%
data4=pd.DataFrame({"Name":['Aman','Joy','Roshni','Saif'], "Age":[20,21,22,23],"Gender":['M','M','F','M']})

# %%
data4
# Out:
#      Name  Age Gender
# 0    Aman   20      M
# 1     Joy   21      M
# 2  Roshni   22      F
# 3    Saif   23      M

# %%
data2=pd.DataFrame({"Name":['Akhil','Asha','Preeti'], "Age":[31,22,24],"Gender":['M','F','F']})

# %%
data4=pd.concat([data,data2],axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\(1)WORK OF HAMZA\VS Code\.vscode\.vscode\python.py\Hamza Lab 18 Aug.ipynb Cell 22 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/%281%29WORK%20OF%20HAMZA/VS%20Code/.vscode/.vscode/python.py/Hamza%20Lab%2018%20Aug.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> data4=pd.concat([data,data2],axis=0)
#
# NameError: name 'data' is not defined

# %%
data3=pd.DataFrame({"School":['A','B','C','D'],"Graduation_name":[57,98,78,89]})

# %%
data5=pd.DataFrame({"Name":['Aman','Joy','Roshni','Saif'], "Age":[20,21,22,23],"Gender":['M','M','F','M']})

# %%
data5=pd.concat([data5,data3],axis=1)

# %%
data5
# Out:
#      Name  Age Gender School  Graduation_name
# 0    Aman   20      M      A               57
# 1     Joy   21      M      B               98
# 2  Roshni   22      F      C               78
# 3    Saif   23      M      D               89

# %%
match=pd.DataFrame({"Name":['csk','rr','rcb','gt','mi'],"Match_played":[10,9,9,8,7],"match_won":[5,6,2,2,1]})

# %%
match
# Out:
#   Name  Match_played  match_won
# 0  csk            10          5
# 1   rr             9          6
# 2  rcb             9          2
# 3   gt             8          2
# 4   mi             7          1

# %%
match2=pd.DataFrame({"Name":['csk','rr','rcb','gt','mi','kkr'],"Match_played":[12,12,12,12,12,12],"match_won":[1,2,3,4,5,6]})

# %%
match2
# Out:
#   Name  Match_played  match_won
# 0  csk            12          1
# 1   rr            12          2
# 2  rcb            12          3
# 3   gt            12          4
# 4   mi            12          5
# 5  kkr            12          6

# %%
match.set_index('Name',inplace=True)

# %%
match2.set_index('Name',inplace=True)

# %%
match2+match
# Out:
#       Match_played  match_won
# Name
# csk           22.0        6.0
# gt            20.0        6.0
# kkr            NaN        NaN
# mi            19.0        6.0
# rcb           21.0        5.0
# rr            21.0        8.0

# %%
match.add(match2,fill_value=0)
# Out:
#       Match_played  match_won
# Name
# csk           22.0        6.0
# gt            20.0        6.0
# kkr           12.0        6.0
# mi            19.0        6.0
# rcb           21.0        5.0
# rr            21.0        8.0
