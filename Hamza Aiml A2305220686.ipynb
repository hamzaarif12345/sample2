# %% [markdown]
# CHECKPOINT 1:
# []: # Path: Data science\Assignment-1\assign.ipynb

# %% [markdown]
# IMPORTING THE LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# READING THE DATASET

# %%
companies=pd.read_csv("companies.txt",sep="\t",encoding='ISO 8859-1')

round2=pd.read_csv("rounds2 - rounds2.csv",encoding='ISO-8859-1')

# %% [markdown]
# INSPECTING THE DATA

# %%
round2.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /ORGANIZATION/-QOUNTER
# 2               /organization/-qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# 4                  A  19-03-2008          2000000.0

# %%
round2.shape
# Out:
# (114949, 6)

# %%
import chardet

rawdata = open('rounds2 - rounds2.csv', 'rb').read()
result = chardet.detect(rawdata)
charenc = result['encoding']
print(charenc)
# Out:
# utf-8

# %%
round2['company_permalink'] = round2.company_permalink.str.encode('utf-8').str.decode('ascii', 'ignore')
round2.loc[~round2['company_permalink'].isin(companies['permalink']), :]
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /organization/-qounter
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /organization/0-6-com
# ...                                                   ...
# 114944                          /organization/zzzzapp-com
# 114945                          /ORGANIZATION/ZZZZAPP-COM
# 114946                                 /organization/eron
# 114947                               /ORGANIZATION/ASYS-2
# 114948  /organization/novatiff-reklam-ve-tantm-hizmetl...
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2       /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3       /funding-round/650b8f704416801069bb178a1418776b            venture
# 4       /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# ...                                                 ...                ...
# 114944  /funding-round/8f6d25b8ee4199e586484d817bceda05   convertible_note
# 114945  /funding-round/ff1aa06ed5da186c84f101549035d4ae               seed
# 114946  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
# 114947  /funding-round/35f09d0794651719b02bbfd859ba9ff5               seed
# 114948  /funding-round/af942869878d2cd788ef5189b435ebc4              grant
#
#        funding_round_code   funded_at  raised_amount_usd
# 0                       B  05-01-2015         10000000.0
# 1                       A  14-10-2014                NaN
# 2                     NaN  01-03-2014           700000.0
# 3                       B  30-01-2014          3406878.0
# 4                       A  19-03-2008          2000000.0
# ...                   ...         ...                ...
# 114944                NaN  01-03-2014            41313.0
# 114945                NaN  01-05-2013            32842.0
# 114946                  A  01-08-2014                NaN
# 114947                NaN  01-01-2015            18192.0
# 114948                NaN  01-10-2013            14851.0
#
# [114949 rows x 6 columns]

# %%
round2.company_permalink=round2.company_permalink.str.lower()

print(round2.company_permalink.nunique())
# Out:
# 66368

# %% [markdown]
# INSPECTING THE COMPANIES DATASET

# %%
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /Organization/-Fame                   #fame
# 1               /Organization/-Qounter                :Qounter
# 2  /Organization/-The-One-Of-Them-Inc-  (THE) ONE of THEM,Inc.
# 3                /Organization/0-6-Com                 0-6.com
# 4       /Organization/004-Technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# 3                                        Curated Web  operating          CHN
# 4                                           Software  operating          USA
#
#   state_code                 region           city  founded_at
# 0         16                 Mumbai         Mumbai         NaN
# 1         DE             DE - Other  Delaware City  04-09-2014
# 2        NaN                    NaN            NaN         NaN
# 3         22                Beijing        Beijing  01-01-2007
# 4         IL  Springfield, Illinois      Champaign  01-01-2010

# %%
companies.permalink=companies.permalink.str.lower()

# %%
companies.shape
# Out:
# (66368, 10)

# %%
companies.permalink.nunique() #permalink check
# Out:
# 66368

# %%
c=companies.permalink.unique()
d=round2.company_permalink.unique()

# %%
companies['permalink'] = companies.permalink.str.encode('utf-8').str.decode('ascii', 'ignore')
companies.loc[~companies['permalink'].isin(round2['company_permalink']), :]
# Out:
#                             permalink                 name  \
# 29218  /organization/its-all-about-me  Itâs All About Me
# 30984          /organization/knownact       knowâNâact
# 58099      /organization/th-gii-di-ng     The Gioi Di Dong
# 63811   /organization/whites-holdings   Whiteâs Holdings
# 63833    /organization/whodats-spaces    Whodatâs Spaces
#
#                          homepage_url category_list     status country_code  \
# 29218         http://iaamadoption.org           NaN  operating          GBR
# 30984             http://knownact.com      Software  operating          USA
# 58099  https://www.thegioididong.com/           NaN  operating          VNM
# 63811                             NaN           NaN  operating          USA
# 63833                             NaN          Apps  operating          NaN
#
#       state_code       region              city founded_at
# 29218         C3  GBR - Other        Saint Ives        NaN
# 30984         WA      Seattle          Bellevue        NaN
# 58099        NaN  Ho Chi Minh  Ho Chi Minh City        NaN
# 63811         PA   Pittsburgh        Washington        NaN
# 63833        NaN          NaN               NaN        NaN

# %% [markdown]
# MERGING THE DATA SETS

# %%
#merging of both data frames on permalink column

master_frame=pd.merge(round2,companies,left_on='company_permalink',right_on='permalink')

# %%
master_frame
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# ...                                                   ...
# 114939                          /organization/zzzzapp-com
# 114940                          /organization/zzzzapp-com
# 114941                                 /organization/eron
# 114942                               /organization/asys-2
# 114943  /organization/novatiff-reklam-ve-tantm-hizmetl...
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2       /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3       /funding-round/650b8f704416801069bb178a1418776b            venture
# 4       /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# ...                                                 ...                ...
# 114939  /funding-round/8f6d25b8ee4199e586484d817bceda05   convertible_note
# 114940  /funding-round/ff1aa06ed5da186c84f101549035d4ae               seed
# 114941  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
# 114942  /funding-round/35f09d0794651719b02bbfd859ba9ff5               seed
# 114943  /funding-round/af942869878d2cd788ef5189b435ebc4              grant
#
#        funding_round_code   funded_at  raised_amount_usd  \
# 0                       B  05-01-2015         10000000.0
# 1                       A  14-10-2014                NaN
# 2                     NaN  01-03-2014           700000.0
# 3                       B  30-01-2014          3406878.0
# 4                       A  19-03-2008          2000000.0
# ...                   ...         ...                ...
# 114939                NaN  01-03-2014            41313.0
# 114940                NaN  01-05-2013            32842.0
# 114941                  A  01-08-2014                NaN
# 114942                NaN  01-01-2015            18192.0
# 114943                NaN  01-10-2013            14851.0
#
#                                                 permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# ...                                                   ...
# 114939                          /organization/zzzzapp-com
# 114940                          /organization/zzzzapp-com
# 114941                                 /organization/eron
# 114942                               /organization/asys-2
# 114943  /organization/novatiff-reklam-ve-tantm-hizmetl...
#
#                                                  name            homepage_url  \
# 0                                               #fame      http://livfame.com
# 1                                            :Qounter  http://www.qounter.com
# 2                                            :Qounter  http://www.qounter.com
# 3                              (THE) ONE of THEM,Inc.     http://oneofthem.jp
# 4                                             0-6.com      http://www.0-6.com
# ...                                               ...                     ...
# 114939                          Zzzzapp Wireless ltd.  http://www.zzzzapp.com
# 114940                          Zzzzapp Wireless ltd.  http://www.zzzzapp.com
# 114941                                         ÃERON    http://www.aeron.hu/
# 114942                                         Ãasys    http://www.oasys.io/
# 114943  Ä°novatiff Reklam ve TanÄ±tÄ±m Hizmetleri Tic    http://inovatiff.com
#
#                                             category_list     status  \
# 0                                                   Media  operating
# 1       Application Platforms|Real Time|Social Network...  operating
# 2       Application Platforms|Real Time|Social Network...  operating
# 3                                       Apps|Games|Mobile  operating
# 4                                             Curated Web  operating
# ...                                                   ...        ...
# 114939        Advertising|Mobile|Web Development|Wireless  operating
# 114940        Advertising|Mobile|Web Development|Wireless  operating
# 114941                                                NaN  operating
# 114942  Consumer Electronics|Internet of Things|Teleco...  operating
# 114943                 Consumer Goods|E-Commerce|Internet  operating
#
#        country_code state_code       region           city  founded_at
# 0               IND         16       Mumbai         Mumbai         NaN
# 1               USA         DE   DE - Other  Delaware City  04-09-2014
# 2               USA         DE   DE - Other  Delaware City  04-09-2014
# 3               NaN        NaN          NaN            NaN         NaN
# 4               CHN         22      Beijing        Beijing  01-01-2007
# ...             ...        ...          ...            ...         ...
# 114939          HRV         15        Split          Split  13-05-2012
# 114940          HRV         15        Split          Split  13-05-2012
# 114941          NaN        NaN          NaN            NaN  01-01-2011
# 114942          USA         CA  SF Bay Area  San Francisco  01-01-2014
# 114943          NaN        NaN          NaN            NaN         NaN
#
# [114944 rows x 16 columns]

# %% [markdown]
# CLEANING THE DATASET

# %%
#checking percentage of null values in the column wrt to total number of rows
master_frame.isnull().sum()*100/master_frame.shape[0]
# Out:
# company_permalink           0.000000
# funding_round_permalink     0.000000
# funding_round_type          0.000000
# funding_round_code         72.908547
# funded_at                   0.000000
# raised_amount_usd          17.389337
# permalink                   0.000000
# name                        0.000870
# homepage_url                5.334772
# category_list               2.964052
# status                      0.000000
# country_code                7.548893
# state_code                  9.521158
# region                      8.844307
# city                        8.841697
# founded_at                 17.848692
# dtype: float64

# %%
#dropping the unwanted columns

master_frame.drop(['funding_round_code','funding_round_permalink',
                   'funded_at','permalink','homepage_url','state_code','city',
                   'region','founded_at','status'],axis=1,inplace=True)

# %%
#now is the turn of dropping rows on the basis of null columns

master_frame=master_frame[~(master_frame.country_code.isnull() | master_frame.raised_amount_usd.isnull() |
                          master_frame.category_list.isnull())]

# %%
master_frame.shape
# Out:
# (88528, 6)

# %% [markdown]
# CHECKPOINT 2

# %%
master_frame.funding_round_type.unique()
# Out:
# array(['venture', 'seed', 'undisclosed', 'convertible_note',
#        'private_equity', 'debt_financing', 'angel', 'grant',
#        'equity_crowdfunding', 'post_ipo_equity', 'post_ipo_debt',
#        'product_crowdfunding', 'secondary_market',
#        'non_equity_assistance'], dtype=object)

# %%
#barplot for funding_round_type(with only fund list) column vs raised_amount_usd column

fund=['angel','seed','venture','private_equity']

plt.figure(figsize=(10,6))
ax=sns.barplot(x='funding_round_type',y='raised_amount_usd',data=master_frame[master_frame.funding_round_type.isin(fund)])

for i in ax.containers:
    ax.bar_label(i,)

plt.show()

# %%
#having only these 4 funding types in master_frame

master_frame=master_frame[master_frame.funding_round_type.isin(fund)]

# %%
master_frame.head()
# Out:
#                      company_permalink funding_round_type  raised_amount_usd  \
# 0                  /organization/-fame            venture         10000000.0
# 2               /organization/-qounter               seed           700000.0
# 4                /organization/0-6-com            venture          2000000.0
# 7  /organization/0ndine-biomedical-inc               seed            43360.0
# 8  /organization/0ndine-biomedical-inc            venture           719491.0
#
#                      name                                      category_list  \
# 0                   #fame                                              Media
# 2                :Qounter  Application Platforms|Real Time|Social Network...
# 4                 0-6.com                                        Curated Web
# 7  Ondine Biomedical Inc.                                      Biotechnology
# 8  Ondine Biomedical Inc.                                      Biotechnology
#
#   country_code
# 0          IND
# 2          USA
# 4          CHN
# 7          CAN
# 8          CAN

# %%
#retaining only venture as it supports the company with 5 to 15 million USD per investment

master_frame=master_frame[master_frame.funding_round_type=='venture']

#now that we know our master frame is having only venture type funding rounds so we can drop the funding_round_type column
master_frame.drop(['funding_round_type'],axis=1,inplace=True)

# %% [markdown]
# CHECKPOINT 3

# %%
master_frame.country_code.unique()
# Out:
# array(['IND', 'CHN', 'CAN', 'USA', 'GBR', 'FRA', 'ROM', 'KOR', 'IRL',
#        'SWE', 'SGP', 'NLD', 'RUS', 'BEL', 'ESP', 'HUN', 'JPN', 'DEU',
#        'ITA', 'HKG', 'BRA', 'FIN', 'CHE', 'PRT', 'SVN', 'THA', 'DNK',
#        'TWN', 'ISR', 'NOR', 'LTU', 'ISL', 'MEX', 'AUS', 'NZL', 'AUT',
#        'ARG', 'PHL', 'MNE', 'MYS', 'TUR', 'POL', 'LVA', 'GGY', 'EST',
#        'LBN', 'GRC', 'IDN', 'CYP', 'SVK', 'ARE', 'EGY', 'ARM', 'ZAF',
#        'TUN', 'KEN', 'COL', 'CZE', 'CMR', 'PRI', 'CYM', 'PER', 'ECU',
#        'CHL', 'NGA', 'VNM', 'URY', 'PAK', 'HRV', 'LUX', 'UKR', 'BMU',
#        'MUS', 'BGR', 'TTO', 'PAN', 'MMR', 'JOR', 'KAZ', 'MAR', 'LIE',
#        'GTM', 'SAU', 'TAN', 'KNA', 'SEN', 'MLT', 'MCO', 'BAH', 'GHA',
#        'KWT', 'UGA', 'LAO', 'BGD', 'BWA', 'MAF', 'GIB'], dtype=object)

# %%
#finding top9 countries with highest number of investments

ax=master_frame.groupby('country_code').raised_amount_usd.sum().nlargest(9).plot(kind='barh')

for i in ax.containers:
    ax.bar_label(i,)

# %%
list=['USA','CHN','GBR','IND','RUS','CAN','FRA','ISR','DEU','JPN']

# %%
#making a data frame with only top9 countries

top9=master_frame[master_frame.country_code.isin(list)]

# %%
top9
# Out:
#                                         company_permalink  raised_amount_usd  \
# 0                                     /organization/-fame         10000000.0
# 4                                   /organization/0-6-com          2000000.0
# 8                     /organization/0ndine-biomedical-inc           719491.0
# 10                                   /organization/0xdata         20000000.0
# 11                                   /organization/0xdata          1700000.0
# ...                                                   ...                ...
# 114917                           /organization/zyomyx-inc         14219999.0
# 114918                           /organization/zyomyx-inc           555016.0
# 114929                                /organization/zyrra           140500.0
# 114931                               /organization/zystor          8500000.0
# 114936  /organization/zznode-science-and-technology-co...          1587301.0
#
#                                  name        category_list country_code
# 0                               #fame                Media          IND
# 4                             0-6.com          Curated Web          CHN
# 8              Ondine Biomedical Inc.        Biotechnology          CAN
# 10                             H2O.ai            Analytics          USA
# 11                             H2O.ai            Analytics          USA
# ...                               ...                  ...          ...
# 114917                         ZYOMYX        Biotechnology          USA
# 114918                         ZYOMYX        Biotechnology          USA
# 114929                          Zyrra           E-Commerce          USA
# 114931                         Zystor        Biotechnology          USA
# 114936  ZZNode Science and Technology  Enterprise Software          CHN
#
# [44318 rows x 5 columns]

# %%
#now by applying the knowledge of languages spoken the top english speaking countries are USA,GBR,IND

master_frame=master_frame[master_frame.country_code.isin(['USA','GBR','IND'])]

# %% [markdown]
# CHECKPOINT 4

# %%
mapping=pd.read_csv("mapping - mapping.csv")

# %%
mapping.isnull().sum()
# Out:
# category_list                              1
# Automotive & Sports                        0
# Blanks                                     0
# Cleantech / Semiconductors                 0
# Entertainment                              0
# Health                                     0
# Manufacturing                              0
# News, Search and Messaging                 0
# Others                                     0
# Social, Finance, Analytics, Advertising    0
# dtype: int64

# %%
#To retrieve the primary sector only
master_frame.category_list=master_frame.category_list.apply(lambda x:x.split('|')[0])

# %%
mapping.category_list=mapping.category_list.replace({'0':'na'}, regex=True)

# %%
mapping.category_list.nunique()
# Out:
# 687

# %%
#To make the table to achieve only primary sector for each category

mapping=pd.melt(mapping,id_vars=['category_list'],value_vars=['Automotive & Sports','Cleantech / Semiconductors',
                                                              'Entertainment','Health','Manufacturing','News, Search and Messaging',
                                                             'Others','Social, Finance, Analytics, Advertising'])

# %%
mapping=mapping[~(mapping.value==0)]

#As job is done so we can drop value column

mapping=mapping.drop(['value'],axis=1)

mapping.head()
# Out:
#        category_list             variable
# 8   Adventure Travel  Automotive & Sports
# 14         Aerospace  Automotive & Sports
# 45              Auto  Automotive & Sports
# 46   Automated Kiosk  Automotive & Sports
# 47        Automotive  Automotive & Sports

# %%
mapping=mapping.rename(columns={'variable':'primary_sector'})

# %%
master_frame=pd.merge(master_frame,mapping,how='left',on='category_list')

# %%
master_frame.head(10)
# Out:
#                company_permalink  raised_amount_usd             name  \
# 0            /organization/-fame         10000000.0            #fame
# 1           /organization/0xdata         20000000.0           H2O.ai
# 2           /organization/0xdata          1700000.0           H2O.ai
# 3           /organization/0xdata          8900000.0           H2O.ai
# 4     /organization/1-mainstream          5000000.0     1 Mainstream
# 5  /organization/10-minutes-with          4000000.0  10 Minutes With
# 6     /organization/1000memories          2520000.0     1000memories
# 7  /organization/1000museums-com           265940.0  1000museums.com
# 8  /organization/1000museums-com          2906832.0  1000museums.com
# 9  /organization/1000museums-com          1500000.0  1000museums.com
#
#   category_list country_code                           primary_sector
# 0         Media          IND                            Entertainment
# 1     Analytics          USA  Social, Finance, Analytics, Advertising
# 2     Analytics          USA  Social, Finance, Analytics, Advertising
# 3     Analytics          USA  Social, Finance, Analytics, Advertising
# 4          Apps          USA               News, Search and Messaging
# 5     Education          GBR                                   Others
# 6   Curated Web          USA               News, Search and Messaging
# 7   Curated Web          USA               News, Search and Messaging
# 8   Curated Web          USA               News, Search and Messaging
# 9   Curated Web          USA               News, Search and Messaging

# %%
#master_frame=master_frame.drop(['primary_sector_y'],axis=1)
master_frame.category_list.nunique()
master_frame=master_frame.rename(columns={'primary_sector_x':'primary_sector'})

# %% [markdown]
# As we have only 563 categories in master_frame and 687 categories in mapping so there might be some categories in master_frame which are not in mapping

# %%
master_frame.head()
master_frame[master_frame.primary_sector.isnull()].category_list.unique()
# Out:
# array(['Nanotechnology', 'Natural Gas Uses',
#        'Natural Language Processing', 'Enterprise 2.0',
#        'Adaptive Equipment', 'Racing', 'Specialty Retail',
#        'Biotechnology and Semiconductor', 'Rapidly Expanding',
#        'Navigation', 'Product Search', 'GreenTech', 'Retirement'],
#       dtype=object)

# %%
#changed by me
#master_frame.primary_sector_y.isnull().sum()

# %%
master_frame=master_frame[~(master_frame.primary_sector.isnull())]

# %%
master_frame.shape
# Out:
# (38638, 6)

# %% [markdown]
# CHECKPOINT 5

# %%
master_frame=master_frame.rename(columns={'primary_sector':'main_sector'})

# %%
master_frame.raised_amount_usd=master_frame.raised_amount_usd/1000000

# %%
D1=master_frame[(master_frame.country_code=='USA') & (master_frame.raised_amount_usd>=5) & (master_frame.raised_amount_usd<=15)]

# %%
D1
# Out:
#                      company_permalink  raised_amount_usd               name  \
# 3                 /organization/0xdata           8.900000             H2O.ai
# 4           /organization/1-mainstream           5.000000       1 Mainstream
# 17        /organization/128-technology          11.999347     128 Technology
# 20     /organization/1366-technologies          15.000000  1366 Technologies
# 21     /organization/1366-technologies           5.000000  1366 Technologies
# ...                                ...                ...                ...
# 38791              /organization/zynga          15.000000              Zynga
# 38794              /organization/zynga           5.026000              Zynga
# 38798         /organization/zyomyx-inc          12.000000             ZYOMYX
# 38799         /organization/zyomyx-inc          14.219999             ZYOMYX
# 38802             /organization/zystor           8.500000             Zystor
#
#                category_list country_code  \
# 3                  Analytics          USA
# 4                       Apps          USA
# 17         Service Providers          USA
# 20             Manufacturing          USA
# 21             Manufacturing          USA
# ...                      ...          ...
# 38791  Facebook Applications          USA
# 38794  Facebook Applications          USA
# 38798          Biotechnology          USA
# 38799          Biotechnology          USA
# 38802          Biotechnology          USA
#
#                                    main_sector
# 3      Social, Finance, Analytics, Advertising
# 4                   News, Search and Messaging
# 17                                      Others
# 20                               Manufacturing
# 21                               Manufacturing
# ...                                        ...
# 38791  Social, Finance, Analytics, Advertising
# 38794  Social, Finance, Analytics, Advertising
# 38798               Cleantech / Semiconductors
# 38799               Cleantech / Semiconductors
# 38802               Cleantech / Semiconductors
#
# [12012 rows x 6 columns]

# %%
D1_part=D1[['raised_amount_usd','main_sector']].groupby('main_sector').agg(['count','sum']).rename(
    columns={'count':'Total_count','sum':'Total_amount'})

D1=D1.merge(D1_part,how='left',on='main_sector')

D1.head()
# Out:
# C:\Users\HAMZA\AppData\Local\Temp\ipykernel_11288\1676402181.py:4: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   D1=D1.merge(D1_part,how='left',on='main_sector')
#                  company_permalink  raised_amount_usd               name  \
# 0             /organization/0xdata           8.900000             H2O.ai
# 1       /organization/1-mainstream           5.000000       1 Mainstream
# 2     /organization/128-technology          11.999347     128 Technology
# 3  /organization/1366-technologies          15.000000  1366 Technologies
# 4  /organization/1366-technologies           5.000000  1366 Technologies
#
#        category_list country_code                              main_sector  \
# 0          Analytics          USA  Social, Finance, Analytics, Advertising
# 1               Apps          USA               News, Search and Messaging
# 2  Service Providers          USA                                   Others
# 3      Manufacturing          USA                            Manufacturing
# 4      Manufacturing          USA                            Manufacturing
#
#    (raised_amount_usd, Total_count)  (raised_amount_usd, Total_amount)
# 0                              2714                       23807.376964
# 1                              1582                       13959.567428
# 2                              2950                       26321.007002
# 3                               799                        7258.553378
# 4                               799                        7258.553378

# %%
D1.sort_values([('raised_amount_usd', 'Total_amount'),'main_sector','raised_amount_usd'],ascending=False)
# Out:
#                 company_permalink  raised_amount_usd             name  \
# 12          /organization/1stdibs               15.0          1stdibs
# 394      /organization/agari-data               15.0            Agari
# 496          /organization/akorri               15.0  Akorri Networks
# 617         /organization/altoweb               15.0          AltoWeb
# 772    /organization/appcelerator               15.0     Appcelerator
# ...                           ...                ...              ...
# 8295       /organization/purecars                5.0         PureCars
# 8399      /organization/quick-hit                5.0        Quick Hit
# 8464       /organization/raidcore                5.0         RAIDCore
# 9239        /organization/sentera                5.0          Sentera
# 9386  /organization/sight-machine                5.0    Sight Machine
#
#             category_list country_code          main_sector  \
# 12             E-Commerce          USA               Others
# 394                  SaaS          USA               Others
# 496              Software          USA               Others
# 617              Software          USA               Others
# 772   Enterprise Software          USA               Others
# ...                   ...          ...                  ...
# 8295           Automotive          USA  Automotive & Sports
# 8399               Sports          USA  Automotive & Sports
# 8464               Design          USA  Automotive & Sports
# 9239            Aerospace          USA  Automotive & Sports
# 9386           Automotive          USA  Automotive & Sports
#
#       (raised_amount_usd, Total_count)  (raised_amount_usd, Total_amount)
# 12                                2950                       26321.007002
# 394                               2950                       26321.007002
# 496                               2950                       26321.007002
# 617                               2950                       26321.007002
# 772                               2950                       26321.007002
# ...                                ...                                ...
# 8295                               167                        1454.104361
# 8399                               167                        1454.104361
# 8464                               167                        1454.104361
# 9239                               167                        1454.104361
# 9386                               167                        1454.104361
#
# [12012 rows x 8 columns]

# %%
D_prac=D1.sort_values([('raised_amount_usd', 'Total_amount'),'main_sector','raised_amount_usd'],ascending=False)
D_prac2=D_prac[D_prac.groupby('main_sector').cumcount()==1]
# Out:
# c:\Python\Python39\lib\site-packages\pandas\core\common.py:241: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = np.asarray(values, dtype=dtype)

# %%
D_prac2
# Out:
#                          company_permalink  raised_amount_usd  \
# 394               /organization/agari-data               15.0
# 294                    /organization/admob               15.0
# 114   /organization/acadia-pharmaceuticals               15.0
# 233                  /organization/adallom               15.0
# 409   /organization/agility-communications               15.0
# 139                /organization/accompany               15.0
# 3272    /organization/dreamworks-animation               15.0
# 3766                 /organization/exostar               15.0
#
#                         name    category_list country_code  \
# 394                    Agari             SaaS          USA
# 294                    AdMob      Advertising          USA
# 114   ACADIA Pharmaceuticals    Biotechnology          USA
# 233                  Adallom  Cloud Computing          USA
# 409   Agility Communications           Lasers          USA
# 139                Accompany               3D          USA
# 3272    DreamWorks Animation    Entertainment          USA
# 3766                 Exostar        Aerospace          USA
#
#                                   main_sector  \
# 394                                    Others
# 294   Social, Finance, Analytics, Advertising
# 114                Cleantech / Semiconductors
# 233                News, Search and Messaging
# 409                                    Health
# 139                             Manufacturing
# 3272                            Entertainment
# 3766                      Automotive & Sports
#
#       (raised_amount_usd, Total_count)  (raised_amount_usd, Total_amount)
# 394                               2950                       26321.007002
# 294                               2714                       23807.376964
# 114                               2300                       21206.628192
# 233                               1582                       13959.567428
# 409                                909                        8211.859357
# 139                                799                        7258.553378
# 3272                               591                        5099.197982
# 3766                               167                        1454.104361

# %%
D2=master_frame[(master_frame.country_code=='GBR') & (master_frame.raised_amount_usd>=5) & (master_frame.raised_amount_usd<=15)]

D2_part=D2[['raised_amount_usd','main_sector']].groupby('main_sector').agg(['count','sum']).rename(
    columns={'count':'Total_count','sum':'Total_amount'})

D2=D2.merge(D2_part,how='left',on='main_sector')

D2.head()
# Out:
# C:\Users\HAMZA\AppData\Local\Temp\ipykernel_11288\3010976895.py:6: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   D2=D2.merge(D2_part,how='left',on='main_sector')
#          company_permalink  raised_amount_usd       name     category_list  \
# 0  /organization/365scores           5.500000  365Scores           Android
# 1   /organization/7digital           8.468328   7digital  Content Creators
# 2   /organization/7digital          10.000000   7digital  Content Creators
# 3      /organization/90min          15.000000      90min             Media
# 4      /organization/90min           5.800000      90min             Media
#
#   country_code                              main_sector  \
# 0          GBR  Social, Finance, Analytics, Advertising
# 1          GBR                            Entertainment
# 2          GBR                            Entertainment
# 3          GBR                            Entertainment
# 4          GBR                            Entertainment
#
#    (raised_amount_usd, Total_count)  (raised_amount_usd, Total_amount)
# 0                               133                        1089.404014
# 1                                56                         482.784687
# 2                                56                         482.784687
# 3                                56                         482.784687
# 4                                56                         482.784687

# %%
D2.sort_values([('raised_amount_usd', 'Total_amount'),'main_sector','raised_amount_usd'],ascending=False)
# Out:
#                     company_permalink  raised_amount_usd                name  \
# 64      /organization/azure-solutions          15.000000     Azure Solutions
# 169       /organization/environmentiq          15.000000       EnvironmentIQ
# 247           /organization/ip-access          15.000000           ip.access
# 358  /organization/notonthehighstreet          15.000000  Notonthehighstreet
# 467             /organization/sensage          15.000000             SenSage
# ..                                ...                ...                 ...
# 600         /organization/yasa-motors           7.576257         YASA Motors
# 102              /organization/carwow           7.230241              Carwow
# 57            /organization/autoquake           6.000000           Autoquake
# 58            /organization/autoquake           5.755376           Autoquake
# 114        /organization/chargemaster           5.133089        Chargemaster
#
#     category_list country_code          main_sector  \
# 64       Software          GBR               Others
# 169      Software          GBR               Others
# 247      Software          GBR               Others
# 358    E-Commerce          GBR               Others
# 467      Security          GBR               Others
# ..            ...          ...                  ...
# 600    Automotive          GBR  Automotive & Sports
# 102    Automotive          GBR  Automotive & Sports
# 57     Automotive          GBR  Automotive & Sports
# 58     Automotive          GBR  Automotive & Sports
# 114    Automotive          GBR  Automotive & Sports
#
#      (raised_amount_usd, Total_count)  (raised_amount_usd, Total_amount)
# 64                                147                        1283.624289
# 169                               147                        1283.624289
# 247                               147                        1283.624289
# 358                               147                        1283.624289
# 467                               147                        1283.624289
# ..                                ...                                ...
# 600                                16                         167.051565
# 102                                16                         167.051565
# 57                                 16                         167.051565
# 58                                 16                         167.051565
# 114                                16                         167.051565
#
# [619 rows x 8 columns]

# %%
D_prac3=D2.sort_values([('raised_amount_usd', 'Total_amount'),'main_sector','raised_amount_usd'],ascending=False)
D_prac4=D_prac3[D_prac3.groupby('main_sector').cumcount()==1]
D_prac4
# Out:
# c:\Python\Python39\lib\site-packages\pandas\core\common.py:241: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = np.asarray(values, dtype=dtype)
#                    company_permalink  raised_amount_usd               name  \
# 169      /organization/environmentiq          15.000000      EnvironmentIQ
# 162            /organization/elixent          15.000000            Elixent
# 384          /organization/opengamma          15.000000          OpenGamma
# 327           /organization/muzicall          13.381200           Muzicall
# 324               /organization/mubi          15.000000               MUBI
# 330             /organization/mydeco          14.529275             mydeco
# 395            /organization/oxonica          14.034694            Oxonica
# 274  /organization/light-blue-optics          15.000000  Light Blue Optics
#
#           category_list country_code                              main_sector  \
# 169            Software          GBR                                   Others
# 162      Semiconductors          GBR               Cleantech / Semiconductors
# 384  Financial Services          GBR  Social, Finance, Analytics, Advertising
# 327              Mobile          GBR               News, Search and Messaging
# 324       Entertainment          GBR                            Entertainment
# 330                  3D          GBR                            Manufacturing
# 395  Health Diagnostics          GBR                                   Health
# 274          Automotive          GBR                      Automotive & Sports
#
#      (raised_amount_usd, Total_count)  (raised_amount_usd, Total_amount)
# 169                               147                        1283.624289
# 162                               128                        1150.139665
# 384                               133                        1089.404014
# 327                                73                         615.746235
# 324                                56                         482.784687
# 330                                42                         361.940335
# 395                                24                         214.537510
# 274                                16                         167.051565

# %%
D3=master_frame[(master_frame.country_code=='IND') & (master_frame.raised_amount_usd>=5) & (master_frame.raised_amount_usd<=15)]

D3_part=D3[['raised_amount_usd','main_sector']].groupby('main_sector').agg(['count','sum']).rename(
    columns={'count':'Total_count','sum':'Total_amount'})

D3=D3.merge(D3_part,how='left',on='main_sector')

D3.head()
# Out:
# C:\Users\HAMZA\AppData\Local\Temp\ipykernel_11288\2792972401.py:6: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   D3=D3.merge(D3_part,how='left',on='main_sector')
#                 company_permalink  raised_amount_usd            name  \
# 0             /organization/-fame          10.000000           #fame
# 1  /organization/21diamonds-india           6.369507      21Diamonds
# 2    /organization/a-little-world           6.410000  A LITTLE WORLD
# 3    /organization/adlabs-imagica           8.180000  Adlabs Imagica
# 4             /organization/agile           5.740000           Agile
#
#    category_list country_code                              main_sector  \
# 0          Media          IND                            Entertainment
# 1     E-Commerce          IND                                   Others
# 2        Finance          IND  Social, Finance, Analytics, Advertising
# 3  Entertainment          IND                            Entertainment
# 4        Finance          IND  Social, Finance, Analytics, Advertising
#
#    (raised_amount_usd, Total_count)  (raised_amount_usd, Total_amount)
# 0                                33                         280.830000
# 1                               110                        1013.409507
# 2                                60                         550.549550
# 3                                33                         280.830000
# 4                                60                         550.549550

# %%
D3.sort_values([('raised_amount_usd', 'Total_amount'),'main_sector','raised_amount_usd'],ascending=False)
# Out:
#                                company_permalink  raised_amount_usd  \
# 41                       /organization/caratlane               15.0
# 52   /organization/classteacher-learning-systems               15.0
# 58              /organization/comat-technologies               15.0
# 59                     /organization/commonfloor               15.0
# 97                    /organization/firstcry-com               15.0
# ..                                           ...                ...
# 324                  /organization/zoomcar-india                8.0
# 191              /organization/mistral-solutions                6.5
# 290                  /organization/tonbo-imaging                6.4
# 8                 /organization/ani-technologies                5.0
# 140                    /organization/indianroots                5.0
#
#                               name category_list country_code  \
# 41                       CaratLane    E-Commerce          IND
# 52   Classteacher Learning Systems        EdTech          IND
# 58              Comat Technologies   Governments          IND
# 59                     CommonFloor   Real Estate          IND
# 97                    FirstCry.com    E-Commerce          IND
# ..                             ...           ...          ...
# 324                        ZoomCar    Automotive          IND
# 191              Mistral Solutions     Aerospace          IND
# 290                  Tonbo Imaging        Design          IND
# 8                              Ola    Automotive          IND
# 140                    IndianRoots     Designers          IND
#
#              main_sector  (raised_amount_usd, Total_count)  \
# 41                Others                               110
# 52                Others                               110
# 58                Others                               110
# 59                Others                               110
# 97                Others                               110
# ..                   ...                               ...
# 324  Automotive & Sports                                13
# 191  Automotive & Sports                                13
# 290  Automotive & Sports                                13
# 8    Automotive & Sports                                13
# 140  Automotive & Sports                                13
#
#      (raised_amount_usd, Total_amount)
# 41                         1013.409507
# 52                         1013.409507
# 58                         1013.409507
# 59                         1013.409507
# 97                         1013.409507
# ..                                 ...
# 324                         136.900000
# 191                         136.900000
# 290                         136.900000
# 8                           136.900000
# 140                         136.900000
#
# [328 rows x 8 columns]

# %%
D_prac5=D3.sort_values([('raised_amount_usd', 'Total_amount'),'main_sector','raised_amount_usd'],ascending=False)
D_prac6=D_prac5[D_prac5.groupby('main_sector').cumcount()==1]
D_prac6
# Out:
# c:\Python\Python39\lib\site-packages\pandas\core\common.py:241: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = np.asarray(values, dtype=dtype)
#                                      company_permalink  raised_amount_usd  \
# 52         /organization/classteacher-learning-systems               15.0
# 95   /organization/financial-information-network-op...               15.0
# 122                                 /organization/hike               14.0
# 196                        /organization/moonfrog-labs               15.0
# 319                     /organization/yuhi-hospitality               15.0
# 151         /organization/ivy-health-and-life-sciences               12.1
# 233                   /organization/perfint-healthcare               14.0
# 136      /organization/incredible-technologies-pvt-ltd               15.0
#
#                                                name        category_list  \
# 52                    Classteacher Learning Systems               EdTech
# 95   Financial Information Network & Operations Pvt              Finance
# 122                                            hike            Messaging
# 196                                   Moonfrog Labs                 Game
# 319                                YUHI Hospitality      Food Processing
# 151                    Ivy Health and Life Sciences  Health and Wellness
# 233                              Perfint Healthcare        Biotechnology
# 136                 Incredible Technologies (CredR)           Automotive
#
#     country_code                              main_sector  \
# 52           IND                                   Others
# 95           IND  Social, Finance, Analytics, Advertising
# 122          IND               News, Search and Messaging
# 196          IND                            Entertainment
# 319          IND                            Manufacturing
# 151          IND                                   Health
# 233          IND               Cleantech / Semiconductors
# 136          IND                      Automotive & Sports
#
#      (raised_amount_usd, Total_count)  (raised_amount_usd, Total_amount)
# 52                                110                        1013.409507
# 95                                 60                         550.549550
# 122                                52                         433.834545
# 196                                33                         280.830000
# 319                                21                         200.900000
# 151                                19                         167.740000
# 233                                20                         165.380000
# 136                                13                         136.900000

# %%
D1.raised_amount_usd.count()
# Out:
# 12012

# %%
D2.raised_amount_usd.count()
# Out:
# 619

# %%
D3.raised_amount_usd.count()
# Out:
# 328

# %%
#total investement in USD for USA, GBR and IND
print(D1.raised_amount_usd.sum())
print(D2.raised_amount_usd.sum())
print(D3.raised_amount_usd.sum())
# Out:
# 107318.29466400002
# 5365.2283
# 2949.5436019999997

# %%
D1_part
# Out:
#                                         raised_amount_usd
#                                               Total_count  Total_amount
# main_sector
# Automotive & Sports                                   167   1454.104361
# Cleantech / Semiconductors                           2300  21206.628192
# Entertainment                                         591   5099.197982
# Health                                                909   8211.859357
# Manufacturing                                         799   7258.553378
# News, Search and Messaging                           1582  13959.567428
# Others                                               2950  26321.007002
# Social, Finance, Analytics, Advertising              2714  23807.376964

# %%
D2_part
# Out:
#                                         raised_amount_usd
#                                               Total_count Total_amount
# main_sector
# Automotive & Sports                                    16   167.051565
# Cleantech / Semiconductors                            128  1150.139665
# Entertainment                                          56   482.784687
# Health                                                 24   214.537510
# Manufacturing                                          42   361.940335
# News, Search and Messaging                             73   615.746235
# Others                                                147  1283.624289
# Social, Finance, Analytics, Advertising               133  1089.404014

# %%
D3_part
# Out:
#                                         raised_amount_usd
#                                               Total_count Total_amount
# main_sector
# Automotive & Sports                                    13   136.900000
# Cleantech / Semiconductors                             20   165.380000
# Entertainment                                          33   280.830000
# Health                                                 19   167.740000
# Manufacturing                                          21   200.900000
# News, Search and Messaging                             52   433.834545
# Others                                                110  1013.409507
# Social, Finance, Analytics, Advertising                60   550.549550

# %%
D1.raised_amount_usd
# Out:
# 0         8.900000
# 1         5.000000
# 2        11.999347
# 3        15.000000
# 4         5.000000
#            ...
# 12007    15.000000
# 12008     5.026000
# 12009    12.000000
# 12010    14.219999
# 12011     8.500000
# Name: raised_amount_usd, Length: 12012, dtype: float64

# %%
D1_part.raised_amount_usd.Total_count
# Out:
# main_sector
# Automotive & Sports                         167
# Cleantech / Semiconductors                 2300
# Entertainment                               591
# Health                                      909
# Manufacturing                               799
# News, Search and Messaging                 1582
# Others                                     2950
# Social, Finance, Analytics, Advertising    2714
# Name: Total_count, dtype: int64

# %%
l1=['Automotive & Sports','Cleantech / Semiconductors','Entertainment','Health',
    'Manufacturing','News, Search and Messaging','Others','Social, Finance, Analytics, Advertising']

plt.figure(figsize=(30,6))
X_axis=np.arange(8)
aux=plt.bar(X_axis ,D1_part.raised_amount_usd.Total_count,0.25,color='red')
aux1=plt.bar(X_axis +0.25,D2_part.raised_amount_usd.Total_count,0.25,color='blue')
aux2=plt.bar(X_axis +0.25*2,D3_part.raised_amount_usd.Total_count,0.25,color='green')

for i in aux,aux1,aux2:
    plt.bar_label(i,)

plt.xticks(X_axis,l1)
plt.legend(['USA','GBR','IND'])
plt.ylabel('Total Investment in 1e7 USD')
plt.show()

# %%
l1=['Automotive & Sports','Cleantech / Semiconductors','Entertainment','Health',
    'Manufacturing','News, Search and Messaging','Others','Social, Finance, Analytics, Advertising']

plt.figure(figsize=(30,6))
X_axis=np.arange(8)
aux=plt.bar(X_axis ,D1_part.raised_amount_usd.Total_amount,0.25,color='red')
aux1=plt.bar(X_axis +0.25,D2_part.raised_amount_usd.Total_amount,0.25,color='blue')
aux2=plt.bar(X_axis +0.25*2,D3_part.raised_amount_usd.Total_amount,0.25,color='green')

for i in aux,aux1,aux2:
    plt.bar_label(i,)

plt.xticks(X_axis,l1)
plt.legend(['USA','GBR','IND'])
plt.ylabel('Total Investment in 1e7 USD')
plt.show()
