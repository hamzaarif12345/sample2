# %%
mydict = {
    'brand': 'hell',
    'year': '2002'
}

# %%
mydict
# Out:
# {'brand': 'hell'}

# %%
mydict.values()
# Out:
# dict_values(['hell'])

# %%
mydict.keys()
# Out:
# dict_keys(['brand'])

# %%
mydict['year']
# Out:
# '2002'
