# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
round_2=pd.read_csv("rounds2 - rounds2.csv",encoding='unicode_escape')
round_2.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /ORGANIZATION/-QOUNTER
# 2               /organization/-qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %%
## how many unique companies are present in round 2
companies=pd.read_csv("companies.txt",sep="\t",encoding='unicode_escape')
companies.isna().sum()
# Out:
# permalink            0
# name                 1
# homepage_url      5058
# category_list     3148
# status               0
# country_code      6958
# state_code        8547
# region            8030
# city              8028
# founded_at       15221
# dtype: int64

# %%
#how many unique companies are present
round_2.company_permalink=round_2.company_permalink.str.lower()
len(round_2.company_permalink.unique())
# Out:
# 66373

# %%
## In compoanies df which column can be used as the unique key for each company? Write the name of the column
if (x not in y for x in round_2.company_permalink.unique() for y in companies.permalink.unique()):
    print('There are some companies in rounds2 file which are not present in companies %%file')
# Out:
# There are some companies in rounds2 file which are not present in companies %%file

# %%
# companies present in rounds file but not in (~) companies file
round_2.loc[~round_2['company_permalink'].isin(companies['permalink']), :]
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# ...                                                   ...
# 114944                          /organization/zzzzapp-com
# 114945                          /organization/zzzzapp-com
# 114946                              /organization/éeron
# 114947                            /organization/è­asys-2
# 114948  /organization/æµnovatiff-reklam-ve-tanæµtæµ...
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# ...

# %%
companies['permalink'] = companies['permalink'].str.lower()
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# ...

# %%
round_2['company_permalink'].nunique()
# Out:
# 66373

# %%
round_2.company_permalink = round_2.company_permalink.str.encode('utf-8').str.decode('ascii', 'ignore')
companies.permalink = companies.permalink.str.encode('utf-8').str.decode('ascii', 'ignore')

# %%
round_2['company_permalink'] = round_2.company_permalink.str.encode('utf-8').str.decode('ascii', 'ignore')
round_2.loc[~round_2['company_permalink'].isin(companies['permalink']), :]
# Out:
#                     company_permalink  \
# 50517   /organization/it-all-about-me
# 53537            /organization/knowct
# 100588       /organization/th-gi-di-g
# 110516   /organization/white-holdings
# 110545    /organization/whodat-spaces
#
#                                 funding_round_permalink funding_round_type  \
# 50517   /funding-round/1f8677102f4445c02ff5ed565e463262        undisclosed
# 53537   /funding-round/5422030afbb191a5e15b3600ff93ab51               seed
# 100588  /funding-round/a49012d798c32ae6c113b8234bdcf804            venture
# 110516  /funding-round/7407f06542934e7dd12beaacc71e8fdc        undisclosed
# 110545  /funding-round/d5d6db3d1e6c54d71a63b3aa0c9278e6               seed
#
#        funding_round_code   funded_at  raised_amount_usd
# 50517                 NaN  01-09-2013                NaN
# 53537                 NaN  12-11-2014           500000.0
# 100588                NaN  28-05-2007          3500000.0
# ...

# %%
master = pd.merge(companies, round_2, how="inner", left_on="permalink", right_on="company_permalink")

# %%
master
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# ...                                                   ...
# 114939                          /organization/zzzzapp-com
# 114940                          /organization/zzzzapp-com
# 114941                                 /organization/eron
# 114942                               /organization/asys-2
# 114943  /organization/novatiff-reklam-ve-tantm-hizmetl...
#
#                                                  name            homepage_url  \
# 0                                               #fame      http://livfame.com
# 1                                            :Qounter  http://www.qounter.com
# ...
